eddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# %%
# embeddings.embed_query("Hello AI")

# %%
res_dim = len(embeddings.embed_query("Hello AI"))
res_dim
# Out:
# 384

# %%
from pinecone import Pinecone

# %%
import os
pinecone_api_key=os.getenv("PINECONE_API_KEY")

# %%
pc=Pinecone(api_key=pinecone_api_key)

# %%
from pinecone import ServerlessSpec
#Serverless: Server will be Managed by the cloud provider

# %%
index_name="agenticbatch2"

# %%
pc.has_index(index_name)
# Out:
# True

# %%
# pc.has_index("trading-bot")

# %%
#creating a index
if not pc.has_index(index_name):
    pc.create_index(
    name=index_name,
    dimension= 384,
    metric="cosine",
    spec=ServerlessSpec(cloud="aws",region="us-east-1")    
)

# %%
#loading the index
index=pc.Index(index_name)

# %%
from langchain_pinecone import PineconeVectorStore

# %%
vector_store = PineconeVectorStore(index=index,embedding=embeddings)

# %%
results = vector_store.similarity_search("what is a langchain?")
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[119], line 1
# ----> 1 results = vector_store.similarity_search("what is a langchain?")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:538, in PineconeVectorStore.similarity_search(self, query, k, filter, namespace, **kwargs)
#     527 """Return pinecone documents most similar to query.
#     528
#     529 Args:
#    (...)    536     List of Documents most similar to the query and score for each
#     537 """
# --> 538 docs_and_scores = self.similarity_search_with_score(
#     539     query, k=k, filter=filter, namespace=namespace, **kwargs
#     540 )
#     541 return [doc for doc, _ in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:41:56 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '943664581484013001', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[119], line 1
# ----> 1 results = vector_store.similarity_search("what is a langchain?")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:538, in PineconeVectorStore.similarity_search(self, query, k, filter, namespace, **kwargs)
#     527 """Return pinecone documents most similar to query.
#     528
#     529 Args:
#    (...)    536     List of Documents most similar to the query and score for each
#     537 """
# --> 538 docs_and_scores = self.similarity_search_with_score(
#     539     query, k=k, filter=filter, namespace=namespace, **kwargs
#     540 )
#     541 return [doc for doc, _ in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:41:56 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '943664581484013001', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 results = vector_store.similarity_search("what is a langchain?")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:538, in PineconeVectorStore.similarity_search(self, query, k, filter, namespace, **kwargs)
#     519 def similarity_search(
#     520     self,
#     521     query: str,
#    (...)    525     **kwargs: Any,
#     526 ) -> List[Document]:
#     527     """Return pinecone documents most similar to query.
#     528
#     529     Args:
#    (...)    536         List of Documents most similar to the query and score for each
#     537     """
# --> 538     docs_and_scores = self.similarity_search_with_score(
#     539         query, k=k, filter=filter, namespace=namespace, **kwargs
#     540     )
#     541     return [doc for doc, _ in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     397 def similarity_search_with_score(
#     398     self,
#     399     query: str,
#    (...)    402     namespace: Optional[str] = None,
#     403 ) -> List[Tuple[Document, float]]:
#     404     """Return pinecone documents most similar to query, along with scores.
#     405
#     406     Args:
#    (...)    413         List of Documents most similar to the query and score for each
#     414     """
# --> 415     return self.similarity_search_by_vector_with_score(
#     416         self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     455     namespace = self._namespace
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#     465     raise ValueError("Received asynchronous result from synchronous call.")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      26     raise ProtocolError(
#      27         "Connection failed. Please verify that the index host is correct and accessible."
#      28     ) from e
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#     335         return response
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     358     raise ValueError("top_k must be a positive integer")
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     386 kwargs = self._process_openapi_kwargs(kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)    383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)    403         body=body,
#     404     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:41:56 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '943664581484013001', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}

# %%
results
# Out:
# []

# %%
from uuid import uuid4
from langchain_core.documents import Document

document_1 = Document(
    page_content="I had chocolate chip pancakes and scrambled eggs for breakfast this morning.",
    metadata={"source": "tweet"},#additional info
)

document_2 = Document(
    page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
    metadata={"source": "news"},
)

document_3 = Document(
    page_content="Building an exciting new project with LangChain - come check it out!",
    metadata={"source": "tweet"},
)

document_4 = Document(
    page_content="Robbers broke into the city bank and stole $1 million in cash.",
    metadata={"source": "news"},
)

document_5 = Document(
    page_content="Wow! That was an amazing movie. I can't wait to see it again.",
    metadata={"source": "tweet"},
)

document_6 = Document(
    page_content="Is the new iPhone worth the price? Read this review to find out.",
    metadata={"source": "website"},
)

document_7 = Document(
    page_content="The top 10 soccer players in the world right now.",
    metadata={"source": "website"},
)

document_8 = Document(
    page_content="LangGraph is the best framework for building stateful, agentic applications!",
    metadata={"source": "tweet"},
)

document_9 = Document(
    page_content="The stock market is down 500 points today due to fears of a recession.",
    metadata={"source": "news"},
)

document_10 = Document(
    page_content="I have a bad feeling I am going to get deleted :(",
    metadata={"source": "tweet"},
)

# %%
documents = [
    document_1,
    document_2,
    document_3,
    document_4,
    document_5,
    document_6,
    document_7,
    document_8,
    document_9,
    document_10,
]

# %%
documents
# Out:
# [Document(metadata={'source': 'tweet'}, page_content='I had chocolate chip pancakes and scrambled eggs for breakfast this morning.'),
#  Document(metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.'),
#  Document(metadata={'source': 'tweet'}, page_content="Wow! That was an amazing movie. I can't wait to see it again."),
#  Document(metadata={'source': 'website'}, page_content='Is the new iPhone worth the price? Read this review to find out.'),
#  Document(metadata={'source': 'website'}, page_content='The top 10 soccer players in the world right now.'),
#  Document(metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!'),
#  Document(metadata={'source': 'news'}, page_content='The stock market is down 500 points today due to fears of a recession.'),
#  Document(metadata={'source': 'tweet'}, page_content='I have a bad feeling I am going to get deleted :(')]

# %%
len(documents)
# Out:
# 10

# %%
range(len(documents))
# Out:
# range(0, 10)

# %%
for _ in range(len(documents)):
    print(_)
    print(str(uuid4()))
# Out:
# 0
# 5d301416-5f82-47aa-86f1-1c86cb41aa96
# 1
# 5a7a4d35-b094-4b4b-ae31-afca90c4a8d0
# 2
# a4232e45-6e71-43a8-8ec6-5575cf63f082
# 3
# c245abad-e1cb-4bb1-b58c-6cbd04867d95
# 4
# 22cbed73-3db2-438e-a160-51b039daeae4
# 5
# acdb6fbf-22c4-4ffd-8a39-ceff50ac5b7e
# 6
# cfa74c59-2ed8-4089-8107-114dbaf1df2e
# 7
# 9a36cef5-bc18-4876-b46d-6889506fca69
# 8
# 54dde3b2-57cd-47d4-a726-aa8c1ce15c49
# 9
# e2b049f2-4b8e-4078-93c1-46b6b54659eb

# %%
#universal indentification number
uuids = [str(uuid4()) for _ in range(len(documents))]

# %%
uuids
# Out:
# ['cb50a721-7be2-48fd-b852-b52e38cd166c',
#  '13aec1e6-ee3b-4a66-b5b0-414839d7827f',
#  '9366ed01-8a04-46b5-97f4-0f387e6e89ce',
#  'a346a543-781e-474a-b9da-e8257a64bdef',
#  '7e796e46-fbdc-45cf-b67e-1818736e5040',
#  'f616c644-7cb7-42e9-8a48-d4fbf090981d',
#  '2f68cbc1-cce1-4a69-88ca-eb686feac054',
#  '5193eba1-729a-4097-aae8-704d51e0c16a',
#  '31576a67-d343-4744-9298-4388d4af9702',
#  '66a49565-156b-47e9-b4d8-c960a41faab2']

# %%
vector_store.add_documents(documents=documents, ids=uuids)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[58], line 1
# ----> 1 vector_store.add_documents(documents=documents, ids=uuids)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:288, in VectorStore.add_documents(self, documents, **kwargs)
#     287     metadatas = [doc.metadata for doc in documents]
# --> 288     return self.add_texts(texts, metadatas, **kwargs)
#     289 msg = (
#     290     f"`add_documents` and `add_texts` has not been implemented "
#     291     f"for {self.__class__.__name__} "
#     292 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:321, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, id_prefix, **kwargs)
#     320     vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
# --> 321     self.index.upsert(
#     322         vectors=vector_tuples,
#     323         namespace=namespace,
#     324         **kwargs,
#     325     )
#     327 return ids
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:188, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     187 if batch_size is None:
# --> 188     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     190 if not isinstance(batch_size, int) or batch_size <= 0:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:214, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     205 def _upsert_batch(
#     206     self,
#     207     vectors: Union[
#    (...)    212     **kwargs,
#     213 ) -> UpsertResponse:
# --> 214     return self._vector_api.upsert_vectors(
#     215         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     216         **self._openapi_kwargs(kwargs),
#     217     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:675, in VectorOperationsApi.__init__.<locals>.__upsert_vectors(self, upsert_request, **kwargs)
#     674 kwargs["upsert_request"] = upsert_request
# --> 675 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:38:19 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '507', 'x-pinecone-request-id': '782690717118657350', 'x-envoy-upstream-service-time': '61', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[58], line 1
# ----> 1 vector_store.add_documents(documents=documents, ids=uuids)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:288, in VectorStore.add_documents(self, documents, **kwargs)
#     287     metadatas = [doc.metadata for doc in documents]
# --> 288     return self.add_texts(texts, metadatas, **kwargs)
#     289 msg = (
#     290     f"`add_documents` and `add_texts` has not been implemented "
#     291     f"for {self.__class__.__name__} "
#     292 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:321, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, id_prefix, **kwargs)
#     320     vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
# --> 321     self.index.upsert(
#     322         vectors=vector_tuples,
#     323         namespace=namespace,
#     324         **kwargs,
#     325     )
#     327 return ids
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:188, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     187 if batch_size is None:
# --> 188     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     190 if not isinstance(batch_size, int) or batch_size <= 0:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:214, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     205 def _upsert_batch(
#     206     self,
#     207     vectors: Union[
#    (...)    212     **kwargs,
#     213 ) -> UpsertResponse:
# --> 214     return self._vector_api.upsert_vectors(
#     215         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     216         **self._openapi_kwargs(kwargs),
#     217     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:675, in VectorOperationsApi.__init__.<locals>.__upsert_vectors(self, upsert_request, **kwargs)
#     674 kwargs["upsert_request"] = upsert_request
# --> 675 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:38:19 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '507', 'x-pinecone-request-id': '782690717118657350', 'x-envoy-upstream-service-time': '61', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 vector_store.add_documents(documents=documents, ids=uuids)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:288, in VectorStore.add_documents(self, documents, **kwargs)
#     286     texts = [doc.page_content for doc in documents]
#     287     metadatas = [doc.metadata for doc in documents]
# --> 288     return self.add_texts(texts, metadatas, **kwargs)
#     289 msg = (
#     290     f"`add_documents` and `add_texts` has not been implemented "
#     291     f"for {self.__class__.__name__} "
#     292 )
#     293 raise NotImplementedError(msg)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:321, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, id_prefix, **kwargs)
#     319     embeddings = self._embedding.embed_documents(chunk_texts)
#     320     vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
# --> 321     self.index.upsert(
#     322         vectors=vector_tuples,
#     323         namespace=namespace,
#     324         **kwargs,
#     325     )
#     327 return ids
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      26     raise ProtocolError(
#      27         "Connection failed. Please verify that the index host is correct and accessible."
#      28     ) from e
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:188, in Index.upsert(self, vectors, namespace, batch_size, show_progress, **kwargs)
#     181     raise ValueError(
#     182         "async_req is not supported when batch_size is provided."
#     183         "To upsert in parallel, please follow: "
#     184         "https://docs.pinecone.io/docs/insert-data#sending-upserts-in-parallel"
#     185     )
#     187 if batch_size is None:
# --> 188     return self._upsert_batch(vectors, namespace, _check_type, **kwargs)
#     190 if not isinstance(batch_size, int) or batch_size <= 0:
#     191     raise ValueError("batch_size must be a positive integer")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:214, in Index._upsert_batch(self, vectors, namespace, _check_type, **kwargs)
#     205 def _upsert_batch(
#     206     self,
#     207     vectors: Union[
#    (...)    212     **kwargs,
#     213 ) -> UpsertResponse:
# --> 214     return self._vector_api.upsert_vectors(
#     215         IndexRequestFactory.upsert_request(vectors, namespace, _check_type, **kwargs),
#     216         **self._openapi_kwargs(kwargs),
#     217     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:675, in VectorOperationsApi.__init__.<locals>.__upsert_vectors(self, upsert_request, **kwargs)
#     673 kwargs = self._process_openapi_kwargs(kwargs)
#     674 kwargs["upsert_request"] = upsert_request
# --> 675 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)    383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)    403         body=body,
#     404     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:38:19 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '507', 'x-pinecone-request-id': '782690717118657350', 'x-envoy-upstream-service-time': '61', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}

# %%
results = vector_store.similarity_search("what langchain provides to us?",k=1)
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[120], line 1
# ----> 1 results = vector_store.similarity_search("what langchain provides to us?",k=1)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:538, in PineconeVectorStore.similarity_search(self, query, k, filter, namespace, **kwargs)
#     527 """Return pinecone documents most similar to query.
#     528
#     529 Args:
#    (...)    536     List of Documents most similar to the query and score for each
#     537 """
# --> 538 docs_and_scores = self.similarity_search_with_score(
#     539     query, k=k, filter=filter, namespace=namespace, **kwargs
#     540 )
#     541 return [doc for doc, _ in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:01 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '8645524194303969041', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[120], line 1
# ----> 1 results = vector_store.similarity_search("what langchain provides to us?",k=1)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:538, in PineconeVectorStore.similarity_search(self, query, k, filter, namespace, **kwargs)
#     527 """Return pinecone documents most similar to query.
#     528
#     529 Args:
#    (...)    536     List of Documents most similar to the query and score for each
#     537 """
# --> 538 docs_and_scores = self.similarity_search_with_score(
#     539     query, k=k, filter=filter, namespace=namespace, **kwargs
#     540 )
#     541 return [doc for doc, _ in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:01 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '8645524194303969041', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 results = vector_store.similarity_search("what langchain provides to us?",k=1)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:538, in PineconeVectorStore.similarity_search(self, query, k, filter, namespace, **kwargs)
#     519 def similarity_search(
#     520     self,
#     521     query: str,
#    (...)    525     **kwargs: Any,
#     526 ) -> List[Document]:
#     527     """Return pinecone documents most similar to query.
#     528
#     529     Args:
#    (...)    536         List of Documents most similar to the query and score for each
#     537     """
# --> 538     docs_and_scores = self.similarity_search_with_score(
#     539         query, k=k, filter=filter, namespace=namespace, **kwargs
#     540     )
#     541     return [doc for doc, _ in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     397 def similarity_search_with_score(
#     398     self,
#     399     query: str,
#    (...)    402     namespace: Optional[str] = None,
#     403 ) -> List[Tuple[Document, float]]:
#     404     """Return pinecone documents most similar to query, along with scores.
#     405
#     406     Args:
#    (...)    413         List of Documents most similar to the query and score for each
#     414     """
# --> 415     return self.similarity_search_by_vector_with_score(
#     416         self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     455     namespace = self._namespace
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#     465     raise ValueError("Received asynchronous result from synchronous call.")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      26     raise ProtocolError(
#      27         "Connection failed. Please verify that the index host is correct and accessible."
#      28     ) from e
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#     335         return response
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     358     raise ValueError("top_k must be a positive integer")
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     386 kwargs = self._process_openapi_kwargs(kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)    383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)    403         body=body,
#     404     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:01 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '8645524194303969041', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}

# %%
results
# Out:
# []

# %%
results = vector_store.similarity_search("what langchain provides to us?",filter={"source": "tweet"})
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[122], line 1
# ----> 1 results = vector_store.similarity_search("what langchain provides to us?",filter={"source": "tweet"})
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:538, in PineconeVectorStore.similarity_search(self, query, k, filter, namespace, **kwargs)
#     527 """Return pinecone documents most similar to query.
#     528
#     529 Args:
#    (...)    536     List of Documents most similar to the query and score for each
#     537 """
# --> 538 docs_and_scores = self.similarity_search_with_score(
#     539     query, k=k, filter=filter, namespace=namespace, **kwargs
#     540 )
#     541 return [doc for doc, _ in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:05 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '7544304806511709754', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[122], line 1
# ----> 1 results = vector_store.similarity_search("what langchain provides to us?",filter={"source": "tweet"})
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:538, in PineconeVectorStore.similarity_search(self, query, k, filter, namespace, **kwargs)
#     527 """Return pinecone documents most similar to query.
#     528
#     529 Args:
#    (...)    536     List of Documents most similar to the query and score for each
#     537 """
# --> 538 docs_and_scores = self.similarity_search_with_score(
#     539     query, k=k, filter=filter, namespace=namespace, **kwargs
#     540 )
#     541 return [doc for doc, _ in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:05 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '7544304806511709754', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 results = vector_store.similarity_search("what langchain provides to us?",filter={"source": "tweet"})
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:538, in PineconeVectorStore.similarity_search(self, query, k, filter, namespace, **kwargs)
#     519 def similarity_search(
#     520     self,
#     521     query: str,
#    (...)    525     **kwargs: Any,
#     526 ) -> List[Document]:
#     527     """Return pinecone documents most similar to query.
#     528
#     529     Args:
#    (...)    536         List of Documents most similar to the query and score for each
#     537     """
# --> 538     docs_and_scores = self.similarity_search_with_score(
#     539         query, k=k, filter=filter, namespace=namespace, **kwargs
#     540     )
#     541     return [doc for doc, _ in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     397 def similarity_search_with_score(
#     398     self,
#     399     query: str,
#    (...)    402     namespace: Optional[str] = None,
#     403 ) -> List[Tuple[Document, float]]:
#     404     """Return pinecone documents most similar to query, along with scores.
#     405
#     406     Args:
#    (...)    413         List of Documents most similar to the query and score for each
#     414     """
# --> 415     return self.similarity_search_by_vector_with_score(
#     416         self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     455     namespace = self._namespace
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#     465     raise ValueError("Received asynchronous result from synchronous call.")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      26     raise ProtocolError(
#      27         "Connection failed. Please verify that the index host is correct and accessible."
#      28     ) from e
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#     335         return response
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     358     raise ValueError("top_k must be a positive integer")
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     386 kwargs = self._process_openapi_kwargs(kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)    383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)    403         body=body,
#     404     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:05 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '7544304806511709754', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}

# %%
results
# Out:
# []

# %%
retriever=vector_store.as_retriever(
    search_type="similarity_score_threshold",
    search_kwargs={"score_threshold": 0.7} #hyperparameter
)

# %%
retriever.invoke("langchain")
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[125], line 1
# ----> 1 retriever.invoke("langchain")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:1082, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1080 elif self.search_type == "similarity_score_threshold":
#    1081     docs_and_similarities = (
# -> 1082         self.vectorstore.similarity_search_with_relevance_scores(
#    1083             query, **_kwargs
#    1084         )
#    1085     )
#    1086     docs = [doc for doc, _ in docs_and_similarities]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:556, in VectorStore.similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     554 score_threshold = kwargs.pop("score_threshold", None)
# --> 556 docs_and_similarities = self._similarity_search_with_relevance_scores(
#     557     query, k=k, **kwargs
#     558 )
#     559 if any(
#     560     similarity < 0.0 or similarity > 1.0
#     561     for _, similarity in docs_and_similarities
#     562 ):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:504, in VectorStore._similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     503 relevance_score_fn = self._select_relevance_score_fn()
# --> 504 docs_and_scores = self.similarity_search_with_score(query, k, **kwargs)
#     505 return [(doc, relevance_score_fn(score)) for doc, score in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:09 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '8471074614350678613', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[125], line 1
# ----> 1 retriever.invoke("langchain")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:1082, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1080 elif self.search_type == "similarity_score_threshold":
#    1081     docs_and_similarities = (
# -> 1082         self.vectorstore.similarity_search_with_relevance_scores(
#    1083             query, **_kwargs
#    1084         )
#    1085     )
#    1086     docs = [doc for doc, _ in docs_and_similarities]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:556, in VectorStore.similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     554 score_threshold = kwargs.pop("score_threshold", None)
# --> 556 docs_and_similarities = self._similarity_search_with_relevance_scores(
#     557     query, k=k, **kwargs
#     558 )
#     559 if any(
#     560     similarity < 0.0 or similarity > 1.0
#     561     for _, similarity in docs_and_similarities
#     562 ):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:504, in VectorStore._similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     503 relevance_score_fn = self._select_relevance_score_fn()
# --> 504 docs_and_scores = self.similarity_search_with_score(query, k, **kwargs)
#     505 return [(doc, relevance_score_fn(score)) for doc, score in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:09 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '8471074614350678613', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 retriever.invoke("langchain")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     257 _kwargs = kwargs if self._expects_other_args else {}
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#     263     result = self._get_relevant_documents(input, **_kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:1082, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1079     docs = self.vectorstore.similarity_search(query, **_kwargs)
#    1080 elif self.search_type == "similarity_score_threshold":
#    1081     docs_and_similarities = (
# -> 1082         self.vectorstore.similarity_search_with_relevance_scores(
#    1083             query, **_kwargs
#    1084         )
#    1085     )
#    1086     docs = [doc for doc, _ in docs_and_similarities]
#    1087 elif self.search_type == "mmr":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:556, in VectorStore.similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     540 """Return docs and relevance scores in the range [0, 1].
#     541
#     542 0 is dissimilar, 1 is most similar.
#    (...)    552     List of Tuples of (doc, similarity_score).
#     553 """
#     554 score_threshold = kwargs.pop("score_threshold", None)
# --> 556 docs_and_similarities = self._similarity_search_with_relevance_scores(
#     557     query, k=k, **kwargs
#     558 )
#     559 if any(
#     560     similarity < 0.0 or similarity > 1.0
#     561     for _, similarity in docs_and_similarities
#     562 ):
#     563     warnings.warn(
#     564         "Relevance scores must be between"
#     565         f" 0 and 1, got {docs_and_similarities}",
#     566         stacklevel=2,
#     567     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:504, in VectorStore._similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     486 """Default similarity search with relevance scores.
#     487
#     488 Modify if necessary in subclass.
#    (...)    501     List of Tuples of (doc, similarity_score)
#     502 """
#     503 relevance_score_fn = self._select_relevance_score_fn()
# --> 504 docs_and_scores = self.similarity_search_with_score(query, k, **kwargs)
#     505 return [(doc, relevance_score_fn(score)) for doc, score in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     397 def similarity_search_with_score(
#     398     self,
#     399     query: str,
#    (...)    402     namespace: Optional[str] = None,
#     403 ) -> List[Tuple[Document, float]]:
#     404     """Return pinecone documents most similar to query, along with scores.
#     405
#     406     Args:
#    (...)    413         List of Documents most similar to the query and score for each
#     414     """
# --> 415     return self.similarity_search_by_vector_with_score(
#     416         self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     455     namespace = self._namespace
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#     465     raise ValueError("Received asynchronous result from synchronous call.")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      26     raise ProtocolError(
#      27         "Connection failed. Please verify that the index host is correct and accessible."
#      28     ) from e
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#     335         return response
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     358     raise ValueError("top_k must be a positive integer")
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     386 kwargs = self._process_openapi_kwargs(kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)    383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)    403         body=body,
#     404     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:09 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '8471074614350678613', 'x-envoy-upstream-service-time': '1', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}

# %%
retriever.invoke("google")
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[126], line 1
# ----> 1 retriever.invoke("google")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:1082, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1080 elif self.search_type == "similarity_score_threshold":
#    1081     docs_and_similarities = (
# -> 1082         self.vectorstore.similarity_search_with_relevance_scores(
#    1083             query, **_kwargs
#    1084         )
#    1085     )
#    1086     docs = [doc for doc, _ in docs_and_similarities]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:556, in VectorStore.similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     554 score_threshold = kwargs.pop("score_threshold", None)
# --> 556 docs_and_similarities = self._similarity_search_with_relevance_scores(
#     557     query, k=k, **kwargs
#     558 )
#     559 if any(
#     560     similarity < 0.0 or similarity > 1.0
#     561     for _, similarity in docs_and_similarities
#     562 ):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:504, in VectorStore._similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     503 relevance_score_fn = self._select_relevance_score_fn()
# --> 504 docs_and_scores = self.similarity_search_with_score(query, k, **kwargs)
#     505 return [(doc, relevance_score_fn(score)) for doc, score in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:13 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '3925861258035989026', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[126], line 1
# ----> 1 retriever.invoke("google")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:1082, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1080 elif self.search_type == "similarity_score_threshold":
#    1081     docs_and_similarities = (
# -> 1082         self.vectorstore.similarity_search_with_relevance_scores(
#    1083             query, **_kwargs
#    1084         )
#    1085     )
#    1086     docs = [doc for doc, _ in docs_and_similarities]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:556, in VectorStore.similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     554 score_threshold = kwargs.pop("score_threshold", None)
# --> 556 docs_and_similarities = self._similarity_search_with_relevance_scores(
#     557     query, k=k, **kwargs
#     558 )
#     559 if any(
#     560     similarity < 0.0 or similarity > 1.0
#     561     for _, similarity in docs_and_similarities
#     562 ):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:504, in VectorStore._similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     503 relevance_score_fn = self._select_relevance_score_fn()
# --> 504 docs_and_scores = self.similarity_search_with_score(query, k, **kwargs)
#     505 return [(doc, relevance_score_fn(score)) for doc, score in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:13 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '3925861258035989026', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 retriever.invoke("google")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     257 _kwargs = kwargs if self._expects_other_args else {}
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#     263     result = self._get_relevant_documents(input, **_kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:1082, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1079     docs = self.vectorstore.similarity_search(query, **_kwargs)
#    1080 elif self.search_type == "similarity_score_threshold":
#    1081     docs_and_similarities = (
# -> 1082         self.vectorstore.similarity_search_with_relevance_scores(
#    1083             query, **_kwargs
#    1084         )
#    1085     )
#    1086     docs = [doc for doc, _ in docs_and_similarities]
#    1087 elif self.search_type == "mmr":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:556, in VectorStore.similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     540 """Return docs and relevance scores in the range [0, 1].
#     541
#     542 0 is dissimilar, 1 is most similar.
#    (...)    552     List of Tuples of (doc, similarity_score).
#     553 """
#     554 score_threshold = kwargs.pop("score_threshold", None)
# --> 556 docs_and_similarities = self._similarity_search_with_relevance_scores(
#     557     query, k=k, **kwargs
#     558 )
#     559 if any(
#     560     similarity < 0.0 or similarity > 1.0
#     561     for _, similarity in docs_and_similarities
#     562 ):
#     563     warnings.warn(
#     564         "Relevance scores must be between"
#     565         f" 0 and 1, got {docs_and_similarities}",
#     566         stacklevel=2,
#     567     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:504, in VectorStore._similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     486 """Default similarity search with relevance scores.
#     487
#     488 Modify if necessary in subclass.
#    (...)    501     List of Tuples of (doc, similarity_score)
#     502 """
#     503 relevance_score_fn = self._select_relevance_score_fn()
# --> 504 docs_and_scores = self.similarity_search_with_score(query, k, **kwargs)
#     505 return [(doc, relevance_score_fn(score)) for doc, score in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     397 def similarity_search_with_score(
#     398     self,
#     399     query: str,
#    (...)    402     namespace: Optional[str] = None,
#     403 ) -> List[Tuple[Document, float]]:
#     404     """Return pinecone documents most similar to query, along with scores.
#     405
#     406     Args:
#    (...)    413         List of Documents most similar to the query and score for each
#     414     """
# --> 415     return self.similarity_search_by_vector_with_score(
#     416         self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     455     namespace = self._namespace
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#     465     raise ValueError("Received asynchronous result from synchronous call.")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      26     raise ProtocolError(
#      27         "Connection failed. Please verify that the index host is correct and accessible."
#      28     ) from e
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#     335         return response
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     358     raise ValueError("top_k must be a positive integer")
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     386 kwargs = self._process_openapi_kwargs(kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)    383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)    403         body=body,
#     404     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:13 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '1', 'x-pinecone-request-id': '3925861258035989026', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model='gemini-1.5-flash')

# %%
from langchain import hub
prompt = hub.pull("rlm/rag-prompt")

# %%
import pprint
pprint.pprint(prompt.messages)
# Out:
# [HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})]

# %% [markdown]
# [HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"), additional_kwargs={})]

# %%
from langchain_core.prompts import PromptTemplate

# %%
prompt=PromptTemplate(
    template="""You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:""",
    input_variables=['context', 'question']
)

# %%
prompt
# Out:
# PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:")

# %%
prompt.invoke({"question":"what is a langchain?","context":"langchain is very super framework for LLM."})
# Out:
# StringPromptValue(text="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: what is a langchain? \nContext: langchain is very super framework for LLM. \nAnswer:")

# %% [markdown]
# StringPromptValue(text="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: what is a langchain? \nContext: langchain is very super framework for LLM. \nAnswer:")

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | model
    | StrOutputParser()
)

# %%
rag_chain.invoke("what is llama model?")
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[137], line 1
# ----> 1 rag_chain.invoke("what is llama model?")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3045, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3044 if i == 0:
# -> 3045     input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3774, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3770         futures = [
#    3771             executor.submit(_invoke_step, step, input, config, key)
#    3772             for key, step in steps.items()
#    3773         ]
# -> 3774         output = {key: future.result() for key, future in zip(steps, futures)}
#    3775 # finish the root run
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3758, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3757 with set_config_context(child_config) as context:
# -> 3758     return context.run(
#    3759         step.invoke,
#    3760         input_,
#    3761         child_config,
#    3762     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3045, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3044 if i == 0:
# -> 3045     input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:1082, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1080 elif self.search_type == "similarity_score_threshold":
#    1081     docs_and_similarities = (
# -> 1082         self.vectorstore.similarity_search_with_relevance_scores(
#    1083             query, **_kwargs
#    1084         )
#    1085     )
#    1086     docs = [doc for doc, _ in docs_and_similarities]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:556, in VectorStore.similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     554 score_threshold = kwargs.pop("score_threshold", None)
# --> 556 docs_and_similarities = self._similarity_search_with_relevance_scores(
#     557     query, k=k, **kwargs
#     558 )
#     559 if any(
#     560     similarity < 0.0 or similarity > 1.0
#     561     for _, similarity in docs_and_similarities
#     562 ):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:504, in VectorStore._similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     503 relevance_score_fn = self._select_relevance_score_fn()
# --> 504 docs_and_scores = self.similarity_search_with_score(query, k, **kwargs)
#     505 return [(doc, relevance_score_fn(score)) for doc, score in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:19 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '6404589832792502574', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[137], line 1
# ----> 1 rag_chain.invoke("what is llama model?")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3045, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3044 if i == 0:
# -> 3045     input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3774, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3770         futures = [
#    3771             executor.submit(_invoke_step, step, input, config, key)
#    3772             for key, step in steps.items()
#    3773         ]
# -> 3774         output = {key: future.result() for key, future in zip(steps, futures)}
#    3775 # finish the root run
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3758, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3757 with set_config_context(child_config) as context:
# -> 3758     return context.run(
#    3759         step.invoke,
#    3760         input_,
#    3761         child_config,
#    3762     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3045, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3044 if i == 0:
# -> 3045     input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:1082, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1080 elif self.search_type == "similarity_score_threshold":
#    1081     docs_and_similarities = (
# -> 1082         self.vectorstore.similarity_search_with_relevance_scores(
#    1083             query, **_kwargs
#    1084         )
#    1085     )
#    1086     docs = [doc for doc, _ in docs_and_similarities]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:556, in VectorStore.similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     554 score_threshold = kwargs.pop("score_threshold", None)
# --> 556 docs_and_similarities = self._similarity_search_with_relevance_scores(
#     557     query, k=k, **kwargs
#     558 )
#     559 if any(
#     560     similarity < 0.0 or similarity > 1.0
#     561     for _, similarity in docs_and_similarities
#     562 ):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:504, in VectorStore._similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     503 relevance_score_fn = self._select_relevance_score_fn()
# --> 504 docs_and_scores = self.similarity_search_with_score(query, k, **kwargs)
#     505 return [(doc, relevance_score_fn(score)) for doc, score in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     404 """Return pinecone documents most similar to query, along with scores.
#     405
#     406 Args:
#    (...)    413     List of Documents most similar to the query and score for each
#     414 """
# --> 415 return self.similarity_search_by_vector_with_score(
#     416     self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      14 try:
# ---> 15     return func(*args, **kwargs)
#      16 except Exception as e:
#      17     # Lazy import of urllib3 exceptions
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      92 """This method is invoked when endpoints are called
#      93 Example:
#      94
#    (...)    100
#     101 """
# --> 102 return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:19 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '6404589832792502574', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
#
#
# The above exception was the direct cause of the following exception:
#
# PineconeApiException                      Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 rag_chain.invoke("what is llama model?")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3045, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3043 with set_config_context(config) as context:
#    3044     if i == 0:
# -> 3045         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046     else:
#    3047         input_ = context.run(step.invoke, input_, config)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3774, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3769     with get_executor_for_config(config) as executor:
#    3770         futures = [
#    3771             executor.submit(_invoke_step, step, input, config, key)
#    3772             for key, step in steps.items()
#    3773         ]
# -> 3774         output = {key: future.result() for key, future in zip(steps, futures)}
#    3775 # finish the root run
#    3776 except BaseException as e:
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3758, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3752 child_config = patch_config(
#    3753     config,
#    3754     # mark each step as a child run
#    3755     callbacks=run_manager.get_child(f"map:key:{key}"),
#    3756 )
#    3757 with set_config_context(child_config) as context:
# -> 3758     return context.run(
#    3759         step.invoke,
#    3760         input_,
#    3761         child_config,
#    3762     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\runnables\base.py:3045, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3043 with set_config_context(config) as context:
#    3044     if i == 0:
# -> 3045         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046     else:
#    3047         input_ = context.run(step.invoke, input_, config)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\retrievers.py:259, in BaseRetriever.invoke(self, input, config, **kwargs)
#     257 _kwargs = kwargs if self._expects_other_args else {}
#     258 if self._new_arg_supported:
# --> 259     result = self._get_relevant_documents(
#     260         input, run_manager=run_manager, **_kwargs
#     261     )
#     262 else:
#     263     result = self._get_relevant_documents(input, **_kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:1082, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1079     docs = self.vectorstore.similarity_search(query, **_kwargs)
#    1080 elif self.search_type == "similarity_score_threshold":
#    1081     docs_and_similarities = (
# -> 1082         self.vectorstore.similarity_search_with_relevance_scores(
#    1083             query, **_kwargs
#    1084         )
#    1085     )
#    1086     docs = [doc for doc, _ in docs_and_similarities]
#    1087 elif self.search_type == "mmr":
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:556, in VectorStore.similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     540 """Return docs and relevance scores in the range [0, 1].
#     541
#     542 0 is dissimilar, 1 is most similar.
#    (...)    552     List of Tuples of (doc, similarity_score).
#     553 """
#     554 score_threshold = kwargs.pop("score_threshold", None)
# --> 556 docs_and_similarities = self._similarity_search_with_relevance_scores(
#     557     query, k=k, **kwargs
#     558 )
#     559 if any(
#     560     similarity < 0.0 or similarity > 1.0
#     561     for _, similarity in docs_and_similarities
#     562 ):
#     563     warnings.warn(
#     564         "Relevance scores must be between"
#     565         f" 0 and 1, got {docs_and_similarities}",
#     566         stacklevel=2,
#     567     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_core\vectorstores\base.py:504, in VectorStore._similarity_search_with_relevance_scores(self, query, k, **kwargs)
#     486 """Default similarity search with relevance scores.
#     487
#     488 Modify if necessary in subclass.
#    (...)    501     List of Tuples of (doc, similarity_score)
#     502 """
#     503 relevance_score_fn = self._select_relevance_score_fn()
# --> 504 docs_and_scores = self.similarity_search_with_score(query, k, **kwargs)
#     505 return [(doc, relevance_score_fn(score)) for doc, score in docs_and_scores]
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:415, in PineconeVectorStore.similarity_search_with_score(self, query, k, filter, namespace)
#     397 def similarity_search_with_score(
#     398     self,
#     399     query: str,
#    (...)    402     namespace: Optional[str] = None,
#     403 ) -> List[Tuple[Document, float]]:
#     404     """Return pinecone documents most similar to query, along with scores.
#     405
#     406     Args:
#    (...)    413         List of Documents most similar to the query and score for each
#     414     """
# --> 415     return self.similarity_search_by_vector_with_score(
#     416         self._embedding.embed_query(query), k=k, filter=filter, namespace=namespace
#     417     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\langchain_pinecone\vectorstores.py:457, in PineconeVectorStore.similarity_search_by_vector_with_score(self, embedding, k, filter, namespace)
#     455     namespace = self._namespace
#     456 docs = []
# --> 457 results = self.index.query(
#     458     vector=embedding,
#     459     top_k=k,
#     460     include_metadata=True,
#     461     namespace=namespace,
#     462     filter=filter,
#     463 )
#     464 if isinstance(results, ApplyResult):
#     465     raise ValueError("Received asynchronous result from synchronous call.")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:30, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      26     raise ProtocolError(
#      27         "Connection failed. Please verify that the index host is correct and accessible."
#      28     ) from e
#      29 else:
# ---> 30     raise e from e
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\utils\error_handling.py:15, in validate_and_convert_errors.<locals>.inner_func(*args, **kwargs)
#      12 @wraps(func)
#      13 def inner_func(*args, **kwargs):
#      14     try:
# ---> 15         return func(*args, **kwargs)
#      16     except Exception as e:
#      17         # Lazy import of urllib3 exceptions
#      18         from urllib3.exceptions import MaxRetryError, ProtocolError as Urllib3ProtocolError
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:321, in Index.query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     307 @validate_and_convert_errors
#     308 def query(
#     309     self,
#    (...)    319     **kwargs,
#     320 ) -> Union[QueryResponse, ApplyResult]:
# --> 321     response = self._query(
#     322         *args,
#     323         top_k=top_k,
#     324         vector=vector,
#     325         id=id,
#     326         namespace=namespace,
#     327         filter=filter,
#     328         include_values=include_values,
#     329         include_metadata=include_metadata,
#     330         sparse_vector=sparse_vector,
#     331         **kwargs,
#     332     )
#     334     if kwargs.get("async_req", False) or kwargs.get("async_threadpool_executor", False):
#     335         return response
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\db_data\index.py:371, in Index._query(self, top_k, vector, id, namespace, filter, include_values, include_metadata, sparse_vector, *args, **kwargs)
#     358     raise ValueError("top_k must be a positive integer")
#     360 request = IndexRequestFactory.query_request(
#     361     top_k=top_k,
#     362     vector=vector,
#    (...)    369     **kwargs,
#     370 )
# --> 371 return self._vector_api.query_vectors(request, **self._openapi_kwargs(kwargs))
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\core\openapi\db_data\api\vector_operations_api.py:388, in VectorOperationsApi.__init__.<locals>.__query_vectors(self, query_request, **kwargs)
#     386 kwargs = self._process_openapi_kwargs(kwargs)
#     387 kwargs["query_request"] = query_request
# --> 388 return self.call_with_http_info(**kwargs)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:306, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     285     return self.threadpool_executor.submit(
#     286         self.__call_api,
#     287         resource_path,
#    (...)    302         _check_type,
#     303     )
#     305 if not async_req:
# --> 306     return self.__call_api(
#     307         resource_path,
#     308         method,
#     309         path_params,
#     310         query_params,
#     311         header_params,
#     312         body,
#     313         post_params,
#     314         files,
#     315         response_type,
#     316         auth_settings,
#     317         _return_http_data_only,
#     318         collection_formats,
#     319         _preload_content,
#     320         _request_timeout,
#     321         _host,
#     322         _check_type,
#     323     )
#     325 return self.pool.apply_async(
#     326     self.__call_api,
#     327     (
#    (...)    344     ),
#     345 )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:182, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
# --> 182     raise e
#     184 self.last_response = response_data
#     186 return_data = response_data
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:170, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     161 url = build_request_url(
#     162     config=config,
#     163     processed_path_params=path_params_tuple,
#     164     resource_path=resource_path,
#     165     _host=_host,
#     166 )
#     168 try:
#     169     # perform request and return response
# --> 170     response_data = self.request(
#     171         method,
#     172         url,
#     173         query_params=processed_query_params,
#     174         headers=headers_tuple,
#     175         post_params=processed_post_params,
#     176         body=body,
#     177         _preload_content=_preload_content,
#     178         _request_timeout=_request_timeout,
#     179     )
#     180 except PineconeApiException as e:
#     181     e.body = e.body.decode("utf-8")
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\api_client.py:386, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     376     return self.rest_client.OPTIONS(
#     377         url,
#     378         query_params=query_params,
#    (...)    383         body=body,
#     384     )
#     385 elif method == "POST":
# --> 386     return self.rest_client.POST(
#     387         url,
#     388         query_params=query_params,
#     389         headers=headers,
#     390         post_params=post_params,
#     391         _preload_content=_preload_content,
#     392         _request_timeout=_request_timeout,
#     393         body=body,
#     394     )
#     395 elif method == "PUT":
#     396     return self.rest_client.PUT(
#     397         url,
#     398         query_params=query_params,
#    (...)    403         body=body,
#     404     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:267, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     264     # log response body
#     265     logger.debug("response body: %s", r.data)
# --> 267 return raise_exceptions_or_return(r)
#
# File c:\MY_Folder\Git_Folders\AgenticAI_Course\agentic_ai_env\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (400)
# Reason: Bad Request
# HTTP response headers: HTTPHeaderDict({'Date': 'Thu, 12 Jun 2025 18:42:19 GMT', 'Content-Type': 'application/json', 'Content-Length': '102', 'Connection': 'keep-alive', 'x-pinecone-request-latency-ms': '0', 'x-pinecone-request-id': '6404589832792502574', 'x-envoy-upstream-service-time': '0', 'server': 'envoy'})
# HTTP response body: {"code":3,"message":"Vector dimension 384 does not match the dimension of the index 768","details":[]}
